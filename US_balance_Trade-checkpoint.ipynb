# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as py




from pathlib import Path
from dotenv import load_dotenv

# %%
us_trade = pd.read_csv("US_ balance_trade.csv", header = 1)
us_trade.head()
# Out:
#    Year Billions of US $ % of GDP
# 0  2018        $-638.21B   -3.10%
# 1  2017        $-575.34B   -2.95%
# 2  2016        $-518.81B   -2.77%
# 3  2015        $-519.85B   -2.85%
# 4  2014        $-507.66B   -2.90%

# %%
us_trade ["% of GDP"] = us_trade['% of GDP'].replace('%','',regex = True)

# %%
us_trade ["Billions of US $"] = us_trade['Billions of US $'].str.replace('$','',regex = True)

# %%
us_trade ["Billions of US $"] = us_trade['Billions of US $'].replace('B','',regex = True)
us_trade
# Out:
#     Year Billions of US $ % of GDP
# 0   2018          -638.21    -3.10
# 1   2017          -575.34    -2.95
# 2   2016          -518.81    -2.77
# 3   2015          -519.85    -2.85
# 4   2014          -507.66    -2.90
# 5   2013          -490.78    -2.92
# 6   2012          -568.57    -3.51
# 7   2011          -579.46    -3.73
# 8   2010          -513.90    -3.43
# 9   2009          -396.45    -2.74
# 10  2008          -723.09    -4.91
# 11  2007          -718.43    -4.97
# 12  2006          -770.93    -5.58
# 13  2005          -721.19    -5.53
# 14  2004          -619.08    -5.07
# 15  2003          -503.13    -4.39
# 16  2002          -425.40    -3.89
# 17  2001          -367.93    -3.48
# 18  2000          -375.05    -3.66
# 19  1999          -255.83    -2.66
# 20  1998          -162.71    -1.80
# 21  1997          -101.97    -1.19
# 22  1996           -96.38    -1.19
# 23  1995           -89.76    -1.17
# 24  1994           -92.49    -1.27
# 25  1993           -65.17    -0.95
# ...

# %%
#Pres_Trump = us_trade.iloc[0:2]
#Pres_Trump
#Pres_Trump.plot (figsize = (20,10), title = 'Pres Trump Balance Trade')
#x = us_trade.year(["2017", "2018"])
#y = us_trade.array([3, 8, 1, 10])

#plt.bar(x,y)
#plt.show()
Pres_Trump = us_trade.iloc[0:2].copy()

Pres_Trump['Billions of US $']=Pres_Trump['Billions of US $'].astype (float) 
Pres_Trump['Year']=Pres_Trump['Year'].astype (float)
Pres_Trump.plot (figsize = (20,10), x= 'Year', y = 'Billions of US $', title = 'Pres Trump Balance Trade')

# %%
Pres_Obama = us_trade.iloc[2:10].copy()

Pres_Obama['Billions of US $']=Pres_Obama['Billions of US $'].astype (float) 
Pres_Obama['Year']=Pres_Obama['Year'].astype (float)
Pres_Obama.plot (figsize = (20,10), x= 'Year', y = 'Billions of US $', title = 'Pres Obama Balance Trade')

# %%
#Pres_W_Bush= us_trade.iloc[10:17]
#Pres_W_Bush.plot bar(x = 'year', y = 'Billions of US $', rot = 0)
Pres_W_Bush = us_trade.iloc[10:17].copy()

Pres_W_Bush['Billions of US $']=Pres_W_Bush['Billions of US $'].astype (float) 
Pres_W_Bush['Year']=Pres_W_Bush['Year'].astype (float)
Pres_W_Bush.plot (figsize = (20,10), x= 'Year', y = 'Billions of US $', title = 'Pres W Bush Balance Trade')

# %%
#Pres_Clinton = us_trade.iloc[17:26]
#Pres_Clinton

Pres_Clinton = us_trade.iloc[17:26].copy()

Pres_Clinton['Billions of US $']=Pres_Clinton['Billions of US $'].astype (float) 
Pres_Clinton['Year']=Pres_Clinton['Year'].astype (float)
Pres_Clinton.plot (figsize = (20,10), x= 'Year', y = 'Billions of US $', title = 'Pres Clinton Balance Trade')

# %%
Pres_H_Bush = us_trade.iloc[25:30]
Pres_H_Bush

Pres_Trump = us_trade.iloc[0:2].copy()

Pres_Trump['Billions of US $']=Pres_Trump['Billions of US $'].astype (float) 
Pres_Trump['Year']=Pres_Trump['Year'].astype (float)
Pres_Trump.plot (figsize = (20,10), x= 'Year', y = 'Billions of US $', title = 'Pres_H_Bush Balance Trade')

# %%
Pres_Reagan = us_trade.iloc[29:38]
Pres_Reagan

Pres_Reagan= us_trade.iloc[29:38].copy()

Pres_Reagan['Billions of US $']=Pres_Reagan['Billions of US $'].astype (float) 
Pres_Reagan['Year']=Pres_Reagan['Year'].astype (float)
Pres_Reagan.plot (figsize = (20,10), x= 'Year', y = 'Billions of US $', title = 'Pres Reagan Balance Trade')
